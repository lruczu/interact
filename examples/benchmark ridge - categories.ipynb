# %%
from functools import reduce
from typing import List

import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model

from interact.fields import FieldsManager, SparseField
from interact.layers import SparseLinear, AddBias
from interact.utils import to_sequences

from utils import get_dataset, DataSet, cost

# %%
train = get_dataset(DataSet.Train)
valid = get_dataset(DataSet.Valid)

# %%
train.head(2)
# Out:
#    Unnamed: 0  train_id                         name  item_condition_id  \
# 0      587969    587969             Men's H&M tshirt                  1
# 1       94528     94528  Victoria Secret Vneck lot 3                  2
#
#                    category_name         brand_name  price  shipping  \
# 0              Men/Tops/T-shirts                H&M    8.0         0
# 1  Women/Tops & Blouses/T-Shirts  Victoria's Secret   13.0         1
#
#                                     item_description
# 0                            Light yellow color, NWT
# 1  victoria-s-secret-pink-essential-v-neck-tee vi...

# %%
valid.head(2)
# Out:
#    Unnamed: 0  train_id                                 name  \
# 0      537620    537620            AE BUNDLE FOR LISA BOWSER
# 1      548690    548690  ***FOR TAM ONLY*** IPAD MINI 4 CASE
#
#    item_condition_id                                      category_name  \
# 0                  2                               Women/Jeans/Boot Cut
# 1                  3  Electronics/Cell Phones & Accessories/Cases, C...
#
#        brand_name  price  shipping  \
# 0  American Eagle  105.0         0
# 1             NaN   10.0         1
#
#                                     item_description
# 0  Size 10 short , Bought these and laundered the...
# 1                                 No description yet

# %%
# %%time
unique_categories = reduce(
    lambda x, y: set(x).union(y),
    np.hstack(
        [
            train['category_name'].fillna('').str.split('/').values,
            valid['category_name'].fillna('').str.split('/').values,
        ]
    )
)
# Out:
# CPU times: user 15.9 s, sys: 146 ms, total: 16 s
# Wall time: 16 s

# %%
len(unique_categories)
# Out:
# 947

# %%
list(unique_categories.difference(''))[0] == ''
# Out:
# True

# %%
category_mapping = {}
for i, category in enumerate(unique_categories):
    if category.strip() == '':
        assert i == 0
        
    category_mapping[category] = i

# %%
category_mapping
# Out:
# {'': 0,
#  'Feather Beds': 1,
#  'Home Decor': 2,
#  'Doormats': 3,
#  'Air Purifiers': 4,
#  "Women's Accessories": 5,
#  'Animals': 6,
#  'Motorcycle & Powersports': 7,
#  'Necklaces': 8,
#  'Light': 9,
#  'Shopping Cart Covers': 10,
#  'Socks': 11,
#  'Photography': 12,
#  'Sweats & Hoodies': 13,
#  'Brass Instruments': 14,
#  'Scale Models': 15,
#  'Skirt': 16,
#  'Lights & Lighting Accessories': 17,
#  'Knit Top': 18,
#  'Snowboard': 19,
#  'Satchel': 20,
#  'Tank': 21,
#  'Crochet': 22,
#  'Health & Baby Care': 23,
#  'Just Married': 24,
#  'Vacuums & Floor Care': 25,
#  'Felted': 26,
#  'Pillows': 27,
#  'Crib Netting': 28,
#  'Bear': 29,
#  'Gift Wrap': 30,
#  'Backpack Style': 31,
#  'Artwork': 32,
#  'Wallets': 33,
#  'Home Surveillance': 34,
#  'Doorstops': 35,
#  'Tiered': 36,
#  'Bottles': 37,
#  'Polo Shirt': 38,
#  'Baby & Child Care': 39,
#  'Nail Care': 40,
#  'Face': 41,
#  'Cross Stitch': 42,
#  'Fabric Postcard': 43,
#  'Suits & Blazers': 44,
#  'Biography': 45,
#  'Lighting & Studio': 46,
#  'Tote': 47,
#  "Kids' Bath": 48,
#  'Fireplaces & Accessories': 49,
#  'Pets': 50,
#  'Baby Gyms & Playmats': 51,
#  'Fiction': 52,
#  'Planters': 53,
#  'Papermaking': 54,
#  'Jewelry': 55,
#  'Boxes': 56,
#  'Towel': 57,
#  'Fitness technology': 58,
#  "Kids' Flatware": 59,
#  'Shams, Bed Skirts & Bed Frame Draperies': 60,
#  'Charm': 61,
#  'Drums & Percussion': 62,
#  'Novelty': 63,
#  'Volleyball': 64,
#  'G-Strings & Thongs': 65,
#  'Magnets': 66,
#  'Cleaning Supplies': 67,
#  'Illustrated': 68,
#  'Hiking & Camping': 69,
#  'Religion & Spirituality': 70,
#  'Corduroys': 71,
#  'Replacement Parts': 72,
#  'Earrings': 73,
#  'Necktie': 74,
#  'Laptops & Netbooks': 75,
#  'Full-Length': 76,
#  'Wool': 77,
#  'Bags and Purses': 78,
#  'Miniature': 79,
#  'Shoes': 80,
#  'Boxing & MMA': 81,
#  'Toys': 82,
#  'Cuff': 83,
#  'Cabinet Locks & Straps': 84,
#  'Hawaiian': 85,
#  "New Year's": 86,
#  'Day of the Dead': 87,
#  'Coaster': 88,
#  'Flashes & Flash Accessories': 89,
#  'Watches': 90,
#  'Flats': 91,
#  'Slim, Skinny': 92,
#  'Bathroom': 93,
#  'Nursery Furniture': 94,
#  'Rainwear': 95,
#  'How to': 96,
#  'Shorts': 97,
#  'Lighting': 98,
#  'Cases, Covers & Skins': 99,
#  'Makeup Palettes': 100,
#  'Embroidery': 101,
#  'School Supplies': 102,
#  'Clothing & Closet Storage': 103,
#  'Humidifiers & Vaporizers': 104,
#  'Fabric': 105,
#  'Bathroom Furniture Sets': 106,
#  'Boys': 107,
#  'Breastfeeding Pillows & Stools': 108,
#  'Shirts & Tops': 109,
#  'Wall Hanging': 110,
#  'Brushes & Applicators': 111,
#  'Football': 112,
#  'Cowl Neck': 113,
#  'Crafting': 114,
#  'Artist Bears': 115,
#  'Action, Adventure': 116,
#  'Furniture': 117,
#  'Birthday': 118,
#  "Men's Golf Clubs": 119,
#  'Basketball': 120,
#  'Zipper': 121,
#  'Women': 122,
#  'Books': 123,
#  'Tennis & Racquets': 124,
#  'Denim': 125,
#  'Supplies': 126,
#  'Cookbook': 127,
#  'Invitations': 128,
#  'Postcard': 129,
#  'Journal': 130,
#  'Pot Holder': 131,
#  'Camcorders': 132,
#  'Office supplies': 133,
#  'Ink & Toner': 134,
#  'Pouch': 135,
#  'Personalized': 136,
#  'Capri, Cropped': 137,
#  'Apron': 138,
#  'Playards': 139,
#  'Teacup': 140,
#  'Towels': 141,
#  'Sweater': 142,
#  'Bookmark': 143,
#  'Paper Goods': 144,
#  'Yarn': 145,
#  'Hip Bag': 146,
#  'Lifestyle & Cultures': 147,
#  'Car Speakers & Systems': 148,
#  'Dress Suit': 149,
#  'Non-Slip Bath Mats': 150,
#  'Digital Cameras': 151,
#  'Styling Products': 152,
#  'Lithographs, Etchings & Woodcuts': 153,
#  'Table': 154,
#  'Game': 155,
#  'Makeup Brushes & Tools': 156,
#  'Feet': 157,
#  'Headphones': 158,
#  'Puzzles': 159,
#  'Novelty & Gag Toys': 160,
#  'Bike & Skate': 161,
#  'Arts & Crafts': 162,
#  'Swim Trunks': 163,
#  'Air Fresheners': 164,
#  'Hat': 165,
#  'Vests': 166,
#  'Tops': 167,
#  'Epilators': 168,
#  'Beads': 169,
#  'Thanksgiving': 170,
#  'NHL': 171,
#  'Outdoors': 172,
#  'Studio Recording Equipment': 173,
#  'Photographs': 174,
#  'Learning & Education': 175,
#  'Beauty': 176,
#  'Daily & Travel items': 177,
#  'Bakeware': 178,
#  'Afghan': 179,
#  'Hair Accessories': 180,
#  'Outerwear': 181,
#  'Gift Sets': 182,
#  'Salt and Pepper Shakers': 183,
#  'Origami': 184,
#  'Figurines': 185,
#  'Area Rugs & Pads': 186,
#  'History': 187,
#  'Home Brewing & Wine Making': 188,
#  'Windbreaker': 189,
#  'Paper Ephemera': 190,
#  'Bead': 191,
#  'Tires & Wheels': 192,
#  'Maternity Pillows': 193,
#  'Candles & Home Scents': 194,
#  'Dinnerware Set': 195,
#  'Bottoms': 196,
#  'Mattress Pads': 197,
#  'Household Supplies': 198,
#  'Radio': 199,
#  'Media': 200,
#  'Others': 201,
#  'Boot Cut': 202,
#  'Animation': 203,
#  'Instrument': 204,
#  'Scrapbooking': 205,
#  'Cables & Adapters': 206,
#  'Thermometers': 207,
#  'Button Down Shirt': 208,
#  'Outdoor Games': 209,
#  'Chair': 210,
#  'Action Figures & Statues': 211,
#  'Comics': 212,
#  'Basic Supplies': 213,
#  'Cape': 214,
#  'Stamps': 215,
#  'Dress - Pleat': 216,
#  'Toddler': 217,
#  'Cleats': 218,
#  'Kitchen Appliances': 219,
#  'Cards': 220,
#  'Polo, Rugby': 221,
#  'Consoles': 222,
#  'Pin': 223,
#  'Golf Balls': 224,
#  'Cotton & Swabs': 225,
#  'Kitchen & Dining': 226,
#  'Kitchen Knives & Cutlery Accessories': 227,
#  'Inflatable Beds': 228,
#  'Asymmetrical Hem': 229,
#  'Needlepoint': 230,
#  'Humidifiers': 231,
#  'Cleaning': 232,
#  'Clocks': 233,
#  'Safety Caps': 234,
#  'Decorative Pillows': 235,
#  'Food Service Equipment & Supplies': 236,
#  'Dusting': 237,
#  'Magazines': 238,
#  'Pillow': 239,
#  'Bed': 240,
#  'Clutch': 241,
#  'Kitchen Utensils & Gadgets': 242,
#  'Home Speakers & Subwoofers': 243,
#  'Cage': 244,
#  'Casual Pants': 245,
#  'Footwear': 246,
#  'Styling Tools': 247,
#  'Tshirt': 248,
#  'Performance Parts & Accessories': 249,
#  'Poetry': 250,
#  'Baskets': 251,
#  'Baguette': 252,
#  'Washers & Dryers': 253,
#  'Cardigan': 254,
#  'Water Sports': 255,
#  'Bowl': 256,
#  'International Publications': 257,
#  'Travel Systems': 258,
#  'Accessory': 259,
#  'Tapestries': 260,
#  'Pumps': 261,
#  'Dolls and Miniatures': 262,
#  'Bass Guitars': 263,
#  'Building Toys': 264,
#  'Wall Decor': 265,
#  'Flare': 266,
#  'Humor': 267,
#  'Fitness accessories': 268,
#  'Bath & Body': 269,
#  'Quilt': 270,
#  'Baby Seats': 271,
#  'Box': 272,
#  'Bras': 273,
#  'Weddings': 274,
#  'Christian Books & Bibles': 275,
#  'Jacket': 276,
#  'Home': 277,
#  'Electronics': 278,
#  'Pants': 279,
#  'Art Doll': 280,
#  'Baseball & Softball': 281,
#  'Wallet': 282,
#  'Military': 283,
#  'Sun': 284,
#  'Science': 285,
#  'TV, Audio & Surveillance': 286,
#  'Storage & Organization': 287,
#  'Carving': 288,
#  'Bedding': 289,
#  'Art': 290,
#  'Magnet': 291,
#  'Leash': 292,
#  'Change Purse': 293,
#  'Keychain': 294,
#  'Makeup Remover': 295,
#  'Nursery Bedding': 296,
#  'Sports & Outdoors': 297,
#  'Lacrosse': 298,
#  'Henley': 299,
#  'Screen Protectors': 300,
#  'Training Pants': 301,
#  'Chargers & Cradles': 302,
#  'Nail Tools': 303,
#  'Drives, Storage & Media': 304,
#  'Pinback Button': 305,
#  'Block': 306,
#  'Hockey': 307,
#  'Paint, Body & Trim': 308,
#  'Small Appliances': 309,
#  'Nails': 310,
#  'Diapering': 311,
#  'Disposable Diapers': 312,
#  'Three Button': 313,
#  'Lenses & Filters': 314,
#  'Garment Steamers': 315,
#  'Fan Shop': 316,
#  'Glassware': 317,
#  'Halter': 318,
#  'Draft Stoppers': 319,
#  "St Patrick's": 320,
#  'Photo Albums & Frames': 321,
#  'Diaper Bag': 322,
#  'MLB': 323,
#  'Highchairs & Booster Seats': 324,
#  'Knitting Supplies': 325,
#  'Food': 326,
#  'Knitting': 327,
#  'Videogame': 328,
#  'Apparel': 329,
#  'Sports Nutrition': 330,
#  'Comic': 331,
#  'Reference': 332,
#  'Car Subwoofers': 333,
#  'Dress Shirts': 334,
#  'Dance': 335,
#  'Serving': 336,
#  'CD': 337,
#  'Figurine': 338,
#  'Exterior Accessories': 339,
#  'Hair Color': 340,
#  'Bicycle Child Seats & Trailers': 341,
#  'Needlecraft': 342,
#  'Other Accessories': 343,
#  'Golf': 344,
#  'Vases': 345,
#  'Cookware': 346,
#  'Holidays': 347,
#  'Travel Bathing Kits': 348,
#  'Decorative Pillows, Inserts & Covers': 349,
#  'Brushes': 350,
#  'Coffee & Tea Accessories': 351,
#  'Duvet Covers & Sets': 352,
#  'Peacoat': 353,
#  'Comforters & Sets': 354,
#  'DJ, Electronic Music & Karaoke': 355,
#  'Gloves': 356,
#  'Candles & Holders': 357,
#  'Organization': 358,
#  'Pet Food': 359,
#  'Posters & Prints': 360,
#  'Work & Safety': 361,
#  'Halloween': 362,
#  'Snowsuits & Bibs': 363,
#  'Shampoos': 364,
#  'Standard': 365,
#  'Child Friendly': 366,
#  'Live Sound & Stage': 367,
#  "Women's Handbags": 368,
#  'Writing': 369,
#  'Soccer': 370,
#  'Baggy, Loose': 371,
#  'Home Décor Accents': 372,
#  'Fantasy': 373,
#  'Medical Books': 374,
#  'Holiday Décor Storage': 375,
#  'Collared': 376,
#  'Athletic Apparel': 377,
#  'Vintage & Collectibles': 378,
#  'Hooded': 379,
#  'Air Conditioners': 380,
#  'Conditioners': 381,
#  'Exercise': 382,
#  'Car Care': 383,
#  'Backpacks, Bags & Briefcases': 384,
#  'Soaps & Cleansers': 385,
#  'Stained Glass': 386,
#  'Valentine': 387,
#  'Office': 388,
#  'Education & Teaching': 389,
#  'Jeans': 390,
#  'Shoulder Bag': 391,
#  'Track & Field': 392,
#  'Pleated': 393,
#  'Gear': 394,
#  'Patriotic': 395,
#  'House': 396,
#  'Paintings': 397,
#  'Sci-Fi, Fantasy': 398,
#  'Pants, Tights, Leggings': 399,
#  'Party Supplies': 400,
#  'Calendars': 401,
#  'Golf Apparel': 402,
#  'Hair': 403,
#  'Safety': 404,
#  'Collar': 405,
#  'NBA': 406,
#  'Literature & Fiction': 407,
#  'Headsets': 408,
#  'Bags & Cases': 409,
#  'Other Furniture': 410,
#  'Clock': 411,
#  'Home Entertainment Furniture': 412,
#  'Something Blue': 413,
#  'Entertainment': 414,
#  'Coats & Jackets': 415,
#  'Paper': 416,
#  'Sheets & Pillowcases': 417,
#  'Cream and Sugar Set': 418,
#  'Tricycles, Scooters & Wagons': 419,
#  'Toiletry Kits': 420,
#  'Presentation': 421,
#  'A-Line': 422,
#  'Favors': 423,
#  'Garage Storage & Organization': 424,
#  'Space Heaters': 425,
#  'Home Appliances': 426,
#  'Overalls': 427,
#  'Quilts': 428,
#  'Pendant': 429,
#  'Men': 430,
#  'Teethers': 431,
#  'Geekery': 432,
#  'Bath Rugs': 433,
#  'Button': 434,
#  'Peasant': 435,
#  'Painting': 436,
#  'Bathing & Skin Care': 437,
#  'Books and Zines': 438,
#  'Baseball': 439,
#  'Khakis, Chinos': 440,
#  'Notebook': 441,
#  'Finding': 442,
#  '100 Years or Older': 443,
#  'Trash & Recycling': 444,
#  'Band & Orchestra': 445,
#  'Casserole': 446,
#  'Athletic': 447,
#  'Carpenter': 448,
#  'Hands & Nails': 449,
#  'Cell Phone Accessories': 450,
#  'Hair & Scalp Treatments': 451,
#  'Hair Care': 452,
#  'Handbag': 453,
#  'Jewelry Boxes & Organizers': 454,
#  'Swings, Jumpers & Bouncers': 455,
#  'Signs': 456,
#  'Prams': 457,
#  'Patchwork': 458,
#  'Medical Supplies & Equipment': 459,
#  'Shelf': 460,
#  'Tank, Cami': 461,
#  'Components & Parts': 462,
#  'Double Breasted': 463,
#  'Hair Relaxers': 464,
#  'Lamps& Accessories': 465,
#  'Bedroom Furniture': 466,
#  'Politics & Social Sciences': 467,
#  'Seasonal': 468,
#  'Loafers & Slip-Ons': 469,
#  'Shampoo & Conditioner Sets': 470,
#  'Book': 471,
#  'Animal': 472,
#  'Bathing Tubs & Seats': 473,
#  'Bathing Accessories': 474,
#  'Toy': 475,
#  'Car Electronics & Accessories': 476,
#  'Storage Cabinets': 477,
#  'Fashion Dolls Apparel': 478,
#  'Pet Lover': 479,
#  'Dresses': 480,
#  'Poster': 481,
#  'Camera': 482,
#  'Bathroom Storage & Organization': 483,
#  'Step Stools': 484,
#  'Household Cleaners': 485,
#  'Teething Relief': 486,
#  'Crewneck': 487,
#  'Turtleneck, Mock': 488,
#  'Video Games & Consoles': 489,
#  'Girls 2T-5T': 490,
#  'Jean Jacket': 491,
#  'Home Décor': 492,
#  'Dining & Entertaining': 493,
#  'Teapot': 494,
#  'Shampoo Plus Conditioner': 495,
#  'Hair Coloring Tools': 496,
#  'One-Piece': 497,
#  'Scoop Neck': 498,
#  'Trash Bags': 499,
#  'Grooming & Healthcare Kits': 500,
#  'Dress': 501,
#  'Shampoo': 502,
#  'Diaper Bags': 503,
#  'Changing Pads & Covers': 504,
#  'RV Parts & Accessories': 505,
#  'Bracelet': 506,
#  'Bomber': 507,
#  'Waxing': 508,
#  'Sports': 509,
#  'Mirrors': 510,
#  'Feeding': 511,
#  'Sun Protection': 512,
#  "Men's Accessories": 513,
#  'Bathroom Furniture': 514,
#  'Pillows & Stools': 515,
#  'Boots': 516,
#  'Cabochon': 517,
#  'Family Planning Tests': 518,
#  'Sweatercoat': 519,
#  'Strategy Guides': 520,
#  'Bathroom Accessories': 521,
#  'Girls (4+)': 522,
#  'T-Shirts': 523,
#  'Mopping': 524,
#  'Blankets & Throws': 525,
#  'Scale Dollhouse Miniature': 526,
#  'Hanukkah': 527,
#  'Wipes & Holders': 528,
#  'Wine Accessories': 529,
#  'Fleece Jacket': 530,
#  'T-shirts': 531,
#  'Belt': 532,
#  'Costume': 533,
#  'Capris, Cropped': 534,
#  'Woodworking': 535,
#  'Home Office Furniture': 536,
#  'Board Shorts': 537,
#  'Baskets & Bins': 538,
#  'Aceo': 539,
#  'Hoodie': 540,
#  'Camera & Photo Accessories': 541,
#  'Brooch': 542,
#  'Window Treatments': 543,
#  'Home Bar Furniture': 544,
#  'Educational': 545,
#  'Seasonal Décor': 546,
#  'Water Coolers & Filters': 547,
#  'Collages': 548,
#  'Dogs': 549,
#  'eBook Access': 550,
#  'Above Knee, Mini': 551,
#  'Equipment': 552,
#  'Televisions': 553,
#  'Scifi': 554,
#  'Sponges': 555,
#  'Mirror': 556,
#  'Hair Perms & Texturizers': 557,
#  'Nasal Aspirators': 558,
#  'Car': 559,
#  'Historical, Military': 560,
#  'Shipping Supplies': 561,
#  'Boys 0-24 Mos': 562,
#  'Kitchen Storage & Organization': 563,
#  'Hobbies': 564,
#  'Tools & Equipment': 565,
#  'Team Sports': 566,
#  'Custom': 567,
#  'Freezers & Ice Makers': 568,
#  'Bouquets': 569,
#  'Mules & Clogs': 570,
#  'Tumbler': 571,
#  'Diaper Pails & Refills': 572,
#  'Board, Surf': 573,
#  'Top & T-shirts': 574,
#  'Binoculars & Telescopes': 575,
#  'Pacifiers & Accessories': 576,
#  'Trim': 577,
#  "Children's Books": 578,
#  'Shawl': 579,
#  'Underwear': 580,
#  'Two Button': 581,
#  'Travel Beds': 582,
#  'Tools & Accessories': 583,
#  'Parka': 584,
#  'Burning': 585,
#  'Hair Loss Products': 586,
#  'NCAA': 587,
#  "Kids' Room Décor": 588,
#  'Watch': 589,
#  'Bed Pillows': 590,
#  'Corset': 591,
#  'Necklace': 592,
#  'Garbage Disposals': 593,
#  'Sports & Outdoor Play': 594,
#  'Car Seats & Accessories': 595,
#  'Living Room Furniture': 596,
#  'Diaper Stackers & Caddies': 597,
#  'Pattern': 598,
#  'Print': 599,
#  'Decorating': 600,
#  'Antique': 601,
#  'Paper Towels': 602,
#  'Stationery': 603,
#  'Sculptures': 604,
#  'Cell Phones & Accessories': 605,
#  'Cargo': 606,
#  'Vest': 607,
#  'Telephone': 608,
#  'Asymmetrical': 609,
#  'Raincoat': 610,
#  'Sets & Kits': 611,
#  "Kids' Furniture": 612,
#  'Plate': 613,
#  'Instructional': 614,
#  'Slippers': 615,
#  'Refrigerators': 616,
#  'Joggers': 617,
#  'Instrument Accessories': 618,
#  'All Other Sports': 619,
#  'Nursery Décor': 620,
#  'Totes & Shoppers': 621,
#  "Kids' Furniture, Décor & Storage": 622,
#  'Bowling': 623,
#  'Tops & T-Shirts': 624,
#  'Sticker': 625,
#  'Skateboard': 626,
#  'Storage & Containers': 627,
#  'Badminton': 628,
#  'Bottle-Feeding': 629,
#  'Vase': 630,
#  'Puffer': 631,
#  'Cameras & Photography': 632,
#  'Luggage': 633,
#  'Golf Shoes': 634,
#  'Kitchen Safety': 635,
#  'Maternity': 636,
#  'Christmas': 637,
#  'eBook Readers': 638,
#  'Linen': 639,
#  'Jerseys': 640,
#  'Film Photography': 641,
#  'Dolls & Accessories': 642,
#  'Hair Styling Tools': 643,
#  'Platter': 644,
#  'Full Zip': 645,
#  'Potty Training': 646,
#  'Toy Remote Control & Play Vehicles': 647,
#  'Cover-Ups': 648,
#  'Laptop': 649,
#  'Health': 650,
#  'Bath': 651,
#  'Interior Accessories': 652,
#  'Collectibles': 653,
#  'Batteries': 654,
#  'Vinyl': 655,
#  'Shrug': 656,
#  'Mid-Calf': 657,
#  'Classic, Straight Leg': 658,
#  'Eyewear': 659,
#  'Candles': 660,
#  'Casual Shorts': 661,
#  'Stationery & Party Supplies': 662,
#  'Activity Centers & Entertainers': 663,
#  'Illustration': 664,
#  "Kids' Bedding": 665,
#  'Ceramics and Pottery': 666,
#  'Religion': 667,
#  'Networking & Connectivity': 668,
#  'Sweeping': 669,
#  'Panties': 670,
#  'Wristlet': 671,
#  'Small Animal': 672,
#  'Yoga & Pilates': 673,
#  'Home Fragrance': 674,
#  'iPad': 675,
#  'Car Seats': 676,
#  'Harnesses & Leashes': 677,
#  'Bathroom Safety': 678,
#  'Sports Bras': 679,
#  'Butter Dish': 680,
#  'Automotive Enthusiast Merchandise': 681,
#  'Oxfords': 682,
#  'Map': 683,
#  'Graphic Design': 684,
#  'Bowls': 685,
#  'Two-Piece': 686,
#  'Jackets': 687,
#  'Baby': 688,
#  'Wind & Woodwind Instruments': 689,
#  'Gates & Doorways': 690,
#  'Girls': 691,
#  'Flatware': 692,
#  'Puzzle': 693,
#  'Poncho': 694,
#  'Doll Clothing': 695,
#  'Boys 2T-5T': 696,
#  'Printmaking': 697,
#  'Slipcovers': 698,
#  'Computers & Tablets': 699,
#  'St Patricks': 700,
#  'Athletic Training': 701,
#  'Kitchen & Table Linens': 702,
#  'Sewing': 703,
#  'Blazer': 704,
#  'Tape': 705,
#  'Eyes': 706,
#  'NFL': 707,
#  'Biographies & Memoirs': 708,
#  'Boyfriend': 709,
#  'Washcloths & Towels': 710,
#  'Outdoor Safety': 711,
#  'Bath Linen Sets': 712,
#  'Blu-Ray': 713,
#  'Candle Holder': 714,
#  'Nonfiction': 715,
#  'Other': 716,
#  'Video Gaming Merchandise': 717,
#  'Musical instruments': 718,
#  'Beach Accessories': 719,
#  "Women's Golf Clubs": 720,
#  'Cosmetic Bags': 721,
#  'Plush': 722,
#  'Video Game': 723,
#  'Ties': 724,
#  'DVD & Blu-ray Players': 725,
#  'Scarf': 726,
#  'Keyboards': 727,
#  'GPS Accessories & Mounts': 728,
#  'Skirts, Skorts & Dresses': 729,
#  'Outdoor': 730,
#  'Monitors': 731,
#  'Turtleneck': 732,
#  'Cleansers': 733,
#  'Tablet': 734,
#  'Wrap': 735,
#  'Frame': 736,
#  'Baby & Toddler Toys': 737,
#  'Dress - Flat Front': 738,
#  'Competitive Swimwear': 739,
#  'Motorcycle': 740,
#  'Bubble': 741,
#  'Tops & Blouses': 742,
#  'Fragrance': 743,
#  'DVD': 744,
#  'Racks, Shelves & Drawers': 745,
#  'Printers, Scanners & Supplies': 746,
#  'Bathroom Shelves': 747,
#  'Portable Audio & Accessories': 748,
#  'Drawings': 749,
#  'Wide Leg': 750,
#  'Electrical Safety': 751,
#  'Lips': 752,
#  'Fans': 753,
#  'Primitive': 754,
#  'Girls 0-24 Mos': 755,
#  'Body': 756,
#  'Straight, Pencil': 757,
#  'Guitars': 758,
#  'Doll Clothes': 759,
#  'Sweaters': 760,
#  'Bubble Bath': 761,
#  'Clothing': 762,
#  'Beading': 763,
#  'Thermal Underwear': 764,
#  'Tuxedo': 765,
#  'Polo': 766,
#  'Dishwashers': 767,
#  'Purse': 768,
#  'Skirt Suit': 769,
#  'Car Security & Convenience': 770,
#  'Makeup Sets': 771,
#  'Dishes': 772,
#  'Rings': 773,
#  'Accessories': 774,
#  'Tiles': 775,
#  'Belts': 776,
#  'Pitcher': 777,
#  'Microphones & Accessories': 778,
#  'Tracksuits & Sweats': 779,
#  'Handmade': 780,
#  'Breastfeeding': 781,
#  'Prenatal Monitoring Devices': 782,
#  'Seat Covers': 783,
#  'Guest Books': 784,
#  'Ring': 785,
#  'Backpacks & Carriers': 786,
#  'Oils & Fluids': 787,
#  'Stuffed Animals & Plush': 788,
#  'Scarves & Wraps': 789,
#  'Stringed Instruments': 790,
#  'Golf Bags': 791,
#  'Skin Care': 792,
#  'Shirt': 793,
#  'Track & Sweat Suits': 794,
#  'Case': 795,
#  'Health Care': 796,
#  'One-Pieces': 797,
#  'Scrubs & Body Treatments': 798,
#  'Sandals': 799,
#  'Vest, Sleeveless': 800,
#  'Linens': 801,
#  'Grooming': 802,
#  'Leg Warmers': 803,
#  'Electronic': 804,
#  'Ornaments': 805,
#  'Tray': 806,
#  'Cozy': 807,
#  'Button-Front': 808,
#  'Lanyard': 809,
#  'Fashion Sneakers': 810,
#  'Advertisement': 811,
#  'Swim Briefs': 812,
#  'Cup': 813,
#  'Entertaining': 814,
#  'Gadgets': 815,
#  'Sleep Positioners': 816,
#  'Souvenir': 817,
#  'Tunic': 818,
#  'Car Video': 819,
#  'Planter': 820,
#  'Pregnancy & Maternity': 821,
#  'Boating': 822,
#  'Coasters': 823,
#  'Trading Cards': 824,
#  'Flight': 825,
#  'Blanket': 826,
#  'Mug': 827,
#  'Cake Toppers': 828,
#  'Pad': 829,
#  'Games': 830,
#  'Track Jacket': 831,
#  'Doll': 832,
#  'Tweezers': 833,
#  'Buckle': 834,
#  'Microwaves': 835,
#  'Indoor': 836,
#  'Trench': 837,
#  'Makeup': 838,
#  'Automotive': 839,
#  'Car Audio, Video & GPS': 840,
#  'Gadget': 841,
#  'Basket': 842,
#  'Dress Up & Pretend Play': 843,
#  'Bed in a Bag': 844,
#  'Maxi': 845,
#  'Electronics for Kids': 846,
#  'Mixed Media': 847,
#  'Changing Kits': 848,
#  'Hats': 849,
#  'V-Neck': 850,
#  'Boys (4+)': 851,
#  'Cloth Diapers': 852,
#  'Storage Solutions': 853,
#  'Straight Leg': 854,
#  'Potties & Seats': 855,
#  'Backpack': 856,
#  'Knee-Length': 857,
#  'Irons & Ironing Boards': 858,
#  'Dehumidifiers': 859,
#  'Paperweights': 860,
#  'Tag': 861,
#  'Leggings': 862,
#  'Decorations': 863,
#  'Powders & Lotions': 864,
#  'Leather': 865,
#  'Dress Pants': 866,
#  'Blazers & Sport Coats': 867,
#  'Swimwear': 868,
#  'Ceramic': 869,
#  'Children': 870,
#  'Strollers': 871,
#  'Walkers': 872,
#  'Price Guides & Publications': 873,
#  'Ballet': 874,
#  "Kids' Home Store": 875,
#  'Laundry Storage & Organization': 876,
#  'VHS': 877,
#  'Relaxed': 878,
#  'Replacement Parts & Tools': 879,
#  'Magic': 880,
#  'Sport': 881,
#  'Human Figure Doll': 882,
#  'Easter': 883,
#  'Varsity': 884,
#  'Carpenter, Utility': 885,
#  'Business & Money': 886,
#  'Personal Care': 887,
#  'Porcelain': 888,
#  'New Years': 889,
#  'Sets': 890,
#  'Sweatshirt, Pullover': 891,
#  'Housewares': 892,
#  'Hobo': 893,
#  'Kitchen': 894,
#  'Edge & Corner Guards': 895,
#  'Dress Shorts': 896,
#  'Calendar': 897,
#  'Bedspreads & Coverlets': 898,
#  'Music': 899,
#  'Pant Suit': 900,
#  'GPS Units & Equipment': 901,
#  'Track & Sweat Pants': 902,
#  'Blouse': 903,
#  'Lingerie': 904,
#  'Horror': 905,
#  'Fishing': 906,
#  'Desktops & All-In-Ones': 907,
#  'Pet Supplies': 908,
#  'Nursery': 909,
#  'Full Skirt': 910,
#  'Arts & Photography': 911,
#  'Science & Math': 912,
#  '50 To 75 Years': 913,
#  'Action Figure': 914,
#  'Kids': 915,
#  'Home Audio': 916,
#  'Playard Bedding': 917,
#  'Handkerchief': 918,
#  'Chain': 919,
#  'Tripods & Supports': 920,
#  'Strength training': 921,
#  'Wine, Beer & Beverage Coolers': 922,
#  'Vintage': 923,
#  'Bracelets': 924,
#  'Suits': 925,
#  'Messenger & Crossbody': 926,
#  'Mini': 927,
#  'Compact': 928,
#  'Patterns': 929,
#  'Cell Phones & Smartphones': 930,
#  '75 To 100 Years': 931,
#  'Sunglasses': 932,
#  'Car Stereos & Components': 933,
#  'One Button': 934,
#  'Television': 935,
#  'Skirts': 936,
#  'Engineering & Transportation': 937,
#  'Lightweight': 938,
#  'Religious': 939,
#  'Patch': 940,
#  'Amplifiers & Effects': 941,
#  'Fixture': 942,
#  'Formal': 943,
#  'Glass': 944,
#  'Cuff Links': 945,
#  'Toothbrushes': 946}

# %%
train['category_name'].fillna('').str.split('/').apply(len).max()
# Out:
# 5

# %%
valid['category_name'].fillna('').str.split('/').apply(len).max()
# Out:
# 5

# %%
from typing import List

def category_to_vector(category: List[str]):
    v = [0] * 5
    for i, c in enumerate(category):
        v[i] = category_mapping[c]
    return v

# %%
X_train_category = train['category_name'].fillna('').str.split('/').apply(category_to_vector)

# %%
X_valid_category = valid['category_name'].fillna('').str.split('/').apply(category_to_vector)

# %%
X_train_category.iloc[:3]
# Out:
# 0    [430, 167, 531, 0, 0]
# 1    [122, 742, 523, 0, 0]
# 2    [122, 377, 679, 0, 0]
# Name: category_name, dtype: object

# %%
X_train_category = np.vstack(X_train_category).astype(np.int32)
X_valid_category = np.vstack(X_valid_category).astype(np.int32)

# %%
X_train_category.max()
# Out:
# 946

# %%
X_valid_category.max()
# Out:
# 946

# %%
f_category = SparseField(
    name='category', 
    vocabulary_size=946,
    m=5, 
    d=5,
)

# %%
i = FieldsManager.fields2inputs([f_category])[0]
sparse_linear = SparseLinear(vocabulary_size=946, alpha=0.001)
o = AddBias()(sparse_linear(i))

# %%
model = Model(i, o)
model.compile(optimizer='sgd', loss='mse')

# %%
model.fit(
    X_train_category, 
    np.log1p(train['price']),
    epochs=10,
    batch_size=32,
    shuffle=True,
    validation_data=(
        X_valid_category,
        np.log1p(valid['price'])
    ), 
    callbacks=[EarlyStopping()]
)
# Out:
# Train on 1082535 samples, validate on 200000 samples
# Epoch 1/10
#      32/1082535 [..............................] - ETA: 2:42:50 - loss: 11.2995
# /home/sigmo/deep/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1082535/1082535 [==============================] - 52s 48us/sample - loss: 0.4614 - val_loss: 0.4479
# Epoch 2/10
# 1082535/1082535 [==============================] - 44s 41us/sample - loss: 0.4473 - val_loss: 0.4466
# Epoch 3/10
# 1082535/1082535 [==============================] - 48s 45us/sample - loss: 0.4470 - val_loss: 0.4467

# %%
y_pred_valid = np.expm1(model.predict(X_valid_category)).flatten()

# %%
cost(true=valid['price'], pred=y_pred_valid)
# Out:
# 0.6600339717368209

# %%
np.mean(
    (np.log1p(valid['price']) - np.log1p(y_pred_valid)) ** 2
)
# Out:
# 0.4356448438466824
